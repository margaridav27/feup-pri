# %%
import pandas as pd
import numpy as np

title_akas = pd.read_csv('../downloads/title.akas.tsv', delimiter='\t', dtype={'isOriginalTitle': object})
title_basics = pd.read_csv('../downloads/title.basics.tsv', delimiter='\t', dtype={'isAdult': object})
title_crew = pd.read_csv('../downloads/title.crew.tsv', delimiter='\t', dtype={'directors': str})
title_ratings = pd.read_csv('../downloads/title.ratings.tsv', delimiter='\t')
name_basics = pd.read_csv('../downloads/name.basics.tsv', delimiter='\t', dtype={'primaryName': str})

# %%
# filter by titleType

title_basics = title_basics[(title_basics['titleType'] == 'movie') | (title_basics['titleType'] == 'tvMovie')]
title_basics.reset_index(inplace=True, drop=True)

# filter by isOriginalTitle

title_akas = title_akas[(title_akas['isOriginalTitle'] == '1') | (title_akas['isOriginalTitle'] == '\\N')]
title_akas.reset_index(inplace=True, drop=True)

# %%
# remove duplicate values with null value in 'isOriginalTitle' column

duplicates = title_akas[title_akas.duplicated(['titleId'])]
duplicates = duplicates[(duplicates['isOriginalTitle'] == '\\N') | (duplicates['attributes'] != '\\N')]

title_akas.drop(labels=duplicates.index, axis=0, inplace=True)
title_akas.reset_index(inplace=True, drop=True)

# %%
duplicates = title_akas[title_akas.duplicated(['titleId'])]

title_akas.drop(labels=duplicates.index, axis=0, inplace=True)
title_akas.reset_index(inplace=True, drop=True)

# %%
# remove movies before a certain year

title_basics['startYear'] = pd.to_numeric(title_basics['startYear'], errors='coerce')
to_remove = title_basics[(title_basics['startYear'] <= 2000) | (title_basics['startYear'] >= 2010)].index
title_basics.drop(to_remove, inplace=True)
title_basics
# Out:
#            tconst titleType  \
# 24415   tt0035423     movie
# 45084   tt0061366     movie
# 50120   tt0067683     movie
# 59666   tt0079644     movie
# 60113   tt0080155     movie
# ...           ...       ...
# 760662  tt9916134     movie
# 760666  tt9916178     movie
# 760668  tt9916188     movie
# 760678  tt9916620     movie
# 760680  tt9916680     movie
#
#                                              primaryTitle  \
# 24415                                      Kate & Leopold
# 45084                                    Around the World
# 50120            Workers '71: Nothing About Us Without Us
# 59666                                       November 1828
# 60113                                 The Wonderful Years
# ...                                                   ...
# 760662                               The Thing in the Bag
# 760666                                 Yesterday's Dreams
# 760668                                           Minotaur
# 760678                                  The Copeland Case
# 760680  De la ilusión al desconcierto: cine colombiano...
#
#                                             originalTitle isAdult  startYear  \
# 24415                                      Kate & Leopold       0     2001.0
# 45084                                    Around the World       0        NaN
# 50120                  Robotnicy 1971 - Nic o nas bez nas       0     2006.0
# 59666                                       November 1828       0     2001.0
# 60113                               Die wunderbaren Jahre       0        NaN
# ...                                                   ...     ...        ...
# 760662                               The Thing in the Bag       0        NaN
# 760666                                 Yesterday's Dreams       0        NaN
# 760668                                           Minotaur       0        NaN
# 760678                                  The Copeland Case       0        NaN
# 760680  De la ilusión al desconcierto: cine colombiano...       0     2007.0
#
#        endYear runtimeMinutes                  genres
# 24415       \N            118  Comedy,Fantasy,Romance
# 45084       \N            178          Comedy,Romance
# 50120       \N             47             Documentary
# 59666       \N            140               Drama,War
# 60113       \N            104                   Drama
# ...        ...            ...                     ...
# 760662      \N             78                      \N
# 760666      \N             \N                      \N
# 760668      \N             \N                Thriller
# 760678      \N             \N                   Drama
# 760680      \N            100             Documentary
#
# [184902 rows x 9 columns]

# %%
# drop useless columns 

title_akas.drop(labels=['ordering', 'types', 'attributes', 'title', 'isOriginalTitle'], axis=1, inplace=True)
title_basics.drop(labels=['endYear', 'titleType'], axis=1, inplace=True)
title_crew.drop(labels=['writers'], axis=1, inplace=True)
title_ratings.drop(labels=['numVotes'], axis=1, inplace=True)
name_basics.drop(labels=['birthYear', 'deathYear', 'primaryProfession', 'knownForTitles'], axis=1, inplace=True)

# %%
title_akas['language'].value_counts()
# Out:
# \N     1790881
# en           4
# tr           1
# yue          1
# da           1
# ca           1
# Name: language, dtype: int64

# %% [markdown]
# :warning:  language column values have little to none importance, hence not using this dataframe

# %%
df = title_basics.merge(
  title_crew, on='tconst', how='left').merge(
    title_ratings, on='tconst', how='left')

df
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0061366                                   Around the World
# 2       tt0067683           Workers '71: Nothing About Us Without Us
# 3       tt0079644                                      November 1828
# 4       tt0080155                                The Wonderful Years
# ...           ...                                                ...
# 184897  tt9916134                               The Thing in the Bag
# 184898  tt9916178                                 Yesterday's Dreams
# 184899  tt9916188                                           Minotaur
# 184900  tt9916620                                  The Copeland Case
# 184901  tt9916680  De la ilusión al desconcierto: cine colombiano...
#
#                                             originalTitle isAdult  startYear  \
# 0                                          Kate & Leopold       0     2001.0
# 1                                        Around the World       0        NaN
# 2                      Robotnicy 1971 - Nic o nas bez nas       0     2006.0
# 3                                           November 1828       0     2001.0
# 4                                   Die wunderbaren Jahre       0        NaN
# ...                                                   ...     ...        ...
# 184897                               The Thing in the Bag       0        NaN
# 184898                                 Yesterday's Dreams       0        NaN
# 184899                                           Minotaur       0        NaN
# 184900                                  The Copeland Case       0        NaN
# 184901  De la ilusión al desconcierto: cine colombiano...       0     2007.0
#
#        runtimeMinutes                  genres            directors  \
# 0                 118  Comedy,Fantasy,Romance            nm0003506
# 1                 178          Comedy,Romance            nm1487785
# 2                  47             Documentary  nm0001425,nm0959099
# 3                 140               Drama,War            nm0440323
# 4                 104                   Drama            nm0475360
# ...               ...                     ...                  ...
# 184897             78                      \N           nm10538318
# 184898             \N                      \N                   \N
# 184899             \N                Thriller            nm2410311
# 184900             \N                   Drama                   \N
# 184901            100             Documentary            nm0652213
#
#         averageRating
# 0                 6.4
# 1                 NaN
# 2                 6.3
# 3                 7.3
# 4                 NaN
# ...               ...
# 184897            NaN
# 184898            NaN
# 184899            NaN
# 184900            NaN
# 184901            NaN
#
# [184902 rows x 9 columns]

# %%
# explode movie rows with more than one director into multiple rows, each one with only one director code

df = df.assign(directors=df['directors'].str.split(',')).explode('directors')
df = df.merge(name_basics, left_on='directors', right_on='nconst', how='left')

# drop useless columns

df.drop(labels=['directors', 'nconst'], axis=1, inplace=True)
df.rename(columns={'primaryName' : 'directors'}, inplace=True)

df
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0061366                                   Around the World
# 2       tt0067683           Workers '71: Nothing About Us Without Us
# 3       tt0067683           Workers '71: Nothing About Us Without Us
# 4       tt0079644                                      November 1828
# ...           ...                                                ...
# 201520  tt9916134                               The Thing in the Bag
# 201521  tt9916178                                 Yesterday's Dreams
# 201522  tt9916188                                           Minotaur
# 201523  tt9916620                                  The Copeland Case
# 201524  tt9916680  De la ilusión al desconcierto: cine colombiano...
#
#                                             originalTitle isAdult  startYear  \
# 0                                          Kate & Leopold       0     2001.0
# 1                                        Around the World       0        NaN
# 2                      Robotnicy 1971 - Nic o nas bez nas       0     2006.0
# 3                      Robotnicy 1971 - Nic o nas bez nas       0     2006.0
# 4                                           November 1828       0     2001.0
# ...                                                   ...     ...        ...
# 201520                               The Thing in the Bag       0        NaN
# 201521                                 Yesterday's Dreams       0        NaN
# 201522                                           Minotaur       0        NaN
# 201523                                  The Copeland Case       0        NaN
# 201524  De la ilusión al desconcierto: cine colombiano...       0     2007.0
#
#        runtimeMinutes                  genres  averageRating  \
# 0                 118  Comedy,Fantasy,Romance            6.4
# 1                 178          Comedy,Romance            NaN
# 2                  47             Documentary            6.3
# 3                  47             Documentary            6.3
# 4                 140               Drama,War            7.3
# ...               ...                     ...            ...
# 201520             78                      \N            NaN
# 201521             \N                      \N            NaN
# 201522             \N                Thriller            NaN
# 201523             \N                   Drama            NaN
# 201524            100             Documentary            NaN
#
#                    directors
# 0              James Mangold
# 1                     Pachhi
# 2       Krzysztof Kieslowski
# 3             Tomasz Zygadlo
# 4                Teguh Karya
# ...                      ...
# 201520         Joseph Graves
# 201521                   NaN
# 201522        Dean Israelite
# 201523                   NaN
# 201524           Luis Ospina
#
# [201525 rows x 9 columns]

# %%
# remove duplicate rows while joining director names

df['directors'] = df['directors'].astype(str)
directors_column = df.groupby(['tconst']).agg({'directors': ', '.join})['directors'].values

df.drop_duplicates(subset='tconst', inplace=True)
df['directors'] = directors_column

df
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0061366                                   Around the World
# 2       tt0067683           Workers '71: Nothing About Us Without Us
# 4       tt0079644                                      November 1828
# 5       tt0080155                                The Wonderful Years
# ...           ...                                                ...
# 201520  tt9916134                               The Thing in the Bag
# 201521  tt9916178                                 Yesterday's Dreams
# 201522  tt9916188                                           Minotaur
# 201523  tt9916620                                  The Copeland Case
# 201524  tt9916680  De la ilusión al desconcierto: cine colombiano...
#
#                                             originalTitle isAdult  startYear  \
# 0                                          Kate & Leopold       0     2001.0
# 1                                        Around the World       0        NaN
# 2                      Robotnicy 1971 - Nic o nas bez nas       0     2006.0
# 4                                           November 1828       0     2001.0
# 5                                   Die wunderbaren Jahre       0        NaN
# ...                                                   ...     ...        ...
# 201520                               The Thing in the Bag       0        NaN
# 201521                                 Yesterday's Dreams       0        NaN
# 201522                                           Minotaur       0        NaN
# 201523                                  The Copeland Case       0        NaN
# 201524  De la ilusión al desconcierto: cine colombiano...       0     2007.0
#
#        runtimeMinutes                  genres  averageRating  \
# 0                 118  Comedy,Fantasy,Romance            6.4
# 1                 178          Comedy,Romance            NaN
# 2                  47             Documentary            6.3
# 4                 140               Drama,War            7.3
# 5                 104                   Drama            NaN
# ...               ...                     ...            ...
# 201520             78                      \N            NaN
# 201521             \N                      \N            NaN
# 201522             \N                Thriller            NaN
# 201523             \N                   Drama            NaN
# 201524            100             Documentary            NaN
#
#                                    directors
# 0                              James Mangold
# 1                                     Pachhi
# 2       Krzysztof Kieslowski, Tomasz Zygadlo
# 4                                Teguh Karya
# 5                               Reiner Kunze
# ...                                      ...
# 201520                         Joseph Graves
# 201521                                   nan
# 201522                        Dean Israelite
# 201523                                   nan
# 201524                           Luis Ospina
#
# [184902 rows x 9 columns]

# %%
df.to_csv('../data/data.csv', index=False, sep=';')

# %% [markdown]
# # TODO:
# - remover filmes mais antigos que x data
# - filtrar filmes apenas em en
#   - not enough values
# - remover filmes sem sinopse (isto é quando formos fazer o webscrapping ig)
