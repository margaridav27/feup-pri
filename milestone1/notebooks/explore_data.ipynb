# %%
import pandas as pd
import numpy as np

title_akas = pd.read_csv('../downloads/title.akas.tsv', delimiter='\t', dtype={'isOriginalTitle': object})
title_basics = pd.read_csv('../downloads/title.basics.tsv', delimiter='\t', dtype={'isAdult': object})
title_crew = pd.read_csv('../downloads/title.crew.tsv', delimiter='\t', dtype={'directors': str})
title_ratings = pd.read_csv('../downloads/title.ratings.tsv', delimiter='\t')
name_basics = pd.read_csv('../downloads/name.basics.tsv', delimiter='\t', dtype={'primaryName': str})

# %%
# filter by titleType

title_basics = title_basics[(title_basics['titleType'] == 'movie') | (title_basics['titleType'] == 'tvMovie')]
title_basics.reset_index(inplace=True, drop=True)

# filter by isOriginalTitle

title_akas = title_akas[(title_akas['isOriginalTitle'] == '1') | (title_akas['isOriginalTitle'] == '\\N')]
title_akas.reset_index(inplace=True, drop=True)

# %%
# remove duplicate values with null value in 'isOriginalTitle' column

duplicates = title_akas[title_akas.duplicated(['titleId'])]
duplicates = duplicates[(duplicates['isOriginalTitle'] == '\\N') | (duplicates['attributes'] != '\\N')]

title_akas.drop(labels=duplicates.index, axis=0, inplace=True)
title_akas.reset_index(inplace=True, drop=True)

# %%
duplicates = title_akas[title_akas.duplicated(['titleId'])]

title_akas.drop(labels=duplicates.index, axis=0, inplace=True)
title_akas.reset_index(inplace=True, drop=True)

# %%
# remove movies before a certain year

title_basics['startYear'] = pd.to_numeric(title_basics['startYear'], errors='coerce')
title_basics = title_basics[title_basics['startYear'] > 1990]
title_basics.reset_index(drop=True, inplace=True)

# %%
# drop useless columns 

title_akas.drop(labels=['ordering', 'types', 'attributes', 'title', 'isOriginalTitle'], axis=1, inplace=True)
title_basics.drop(labels=['endYear', 'titleType'], axis=1, inplace=True)
title_crew.drop(labels=['writers'], axis=1, inplace=True)
title_ratings.drop(labels=['numVotes'], axis=1, inplace=True)
name_basics.drop(labels=['birthYear', 'deathYear', 'primaryProfession', 'knownForTitles'], axis=1, inplace=True)

# %%
title_akas['language'].value_counts()
# Out:
# \N     1790606
# en           4
# tr           1
# yue          1
# da           1
# ca           1
# Name: language, dtype: int64

# %% [markdown]
# :warning:  language column values have little to none importance, hence not using this dataframe

# %%
df = title_basics.merge(
  title_crew, on='tconst', how='left').merge(
    title_ratings, on='tconst', how='left')

df
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0011801                                   Tötet nicht mehr
# 1       tt0013274                        Istoriya grazhdanskoy voyny
# 2       tt0015414                             La tierra de los toros
# 3       tt0015724                                      Dama de noche
# 4       tt0035423                                     Kate & Leopold
# ...           ...                                                ...
# 414115  tt9916680  De la ilusión al desconcierto: cine colombiano...
# 414116  tt9916692                    Teatroteka: Czlowiek bez twarzy
# 414117  tt9916706                                    Dankyavar Danka
# 414118  tt9916730                                             6 Gunn
# 414119  tt9916754                     Chico Albuquerque - Revelações
#
#                                             originalTitle isAdult  startYear  \
# 0                                        Tötet nicht mehr       0     2019.0
# 1                             Istoriya grazhdanskoy voyny       0     2021.0
# 2                                  La tierra de los toros       0     2000.0
# 3                                           Dama de noche       0     1993.0
# 4                                          Kate & Leopold       0     2001.0
# ...                                                   ...     ...        ...
# 414115  De la ilusión al desconcierto: cine colombiano...       0     2007.0
# 414116                    Teatroteka: Czlowiek bez twarzy       0     2015.0
# 414117                                    Dankyavar Danka       0     2013.0
# 414118                                             6 Gunn       0     2017.0
# 414119                     Chico Albuquerque - Revelações       0     2013.0
#
#        runtimeMinutes                  genres            directors  \
# 0                  \N            Action,Crime            nm0681726
# 1                 133             Documentary  nm0412842,nm0895048
# 2                  60                      \N            nm0615736
# 3                 102   Drama,Mystery,Romance            nm0529960
# 4                 118  Comedy,Fantasy,Romance            nm0003506
# ...               ...                     ...                  ...
# 414115            100             Documentary            nm0652213
# 414116             66                   Drama           nm10538592
# 414117             \N                  Comedy            nm7764440
# 414118            116                      \N           nm10538612
# 414119             49             Documentary  nm8349149,nm9272490
#
#         averageRating
# 0                 NaN
# 1                 6.4
# 2                 5.3
# 3                 6.1
# 4                 6.4
# ...               ...
# 414115            NaN
# 414116            NaN
# 414117            NaN
# 414118            8.4
# 414119            NaN
#
# [414120 rows x 9 columns]

# %%
df = df[(not df['averageRating'].isnull()) & (df['averageRating'] >= 7)]
df.reset_index(inplace=True, drop=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/beatrizag__/Desktop/uni/PRI/feup-pri/Milestone1/src/prepare_data.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/beatrizag__/Desktop/uni/PRI/feup-pri/Milestone1/src/prepare_data.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> df = df[(not df['averageRating'].isnull()) & (df['averageRating'] >= 7)]
#       <a href='vscode-notebook-cell:/Users/beatrizag__/Desktop/uni/PRI/feup-pri/Milestone1/src/prepare_data.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> df.reset_index(inplace=True, drop=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# explode movie rows with more than one director into multiple rows, each one with only one director code

df = df.assign(directors=df['directors'].str.split(',')).explode('directors')
df = df.merge(name_basics, left_on='directors', right_on='nconst', how='left')

# drop useless columns

df.drop(labels=['directors', 'nconst'], axis=1, inplace=True)
df.rename(columns={'primaryName' : 'directors'}, inplace=True)

df
# Out:
#           tconst                                primaryTitle  \
# 0      tt0038086                   Shiva und die Galgenblume
# 1      tt0079644                               November 1828
# 2      tt0084015                            Goodbye Paradise
# 3      tt0084015                            Goodbye Paradise
# 4      tt0084660                                    Sentinel
# ...          ...                                         ...
# 84932  tt9916170                               The Rehearsal
# 84933  tt9916192  Danielle Darrieux: Il est poli d'être gai!
# 84934  tt9916460                                   Pink Taxi
# 84935  tt9916538                         Kuambil Lagi Hatiku
# 84936  tt9916730                                      6 Gunn
#
#                                     originalTitle isAdult  startYear  \
# 0                       Shiva und die Galgenblume       0     1993.0
# 1                                   November 1828       0     2001.0
# 2                                Goodbye Paradise       0     1991.0
# 3                                Goodbye Paradise       0     1991.0
# 4                                        Sentinel       0     1993.0
# ...                                           ...     ...        ...
# 84932                                    O Ensaio       0     2019.0
# 84933  Danielle Darrieux: Il est poli d'être gai!       0     2019.0
# 84934                                   Pink Taxi       0     2019.0
# 84935                         Kuambil Lagi Hatiku       0     2019.0
# 84936                                      6 Gunn       0     2017.0
#
#       runtimeMinutes            genres  averageRating            directors
# 0                 \N          Thriller            7.0       Hans Steinhoff
# 1                140         Drama,War            7.3          Teguh Karya
# 2                101             Drama            7.2           Tim Savage
# 3                101             Drama            7.2  Dennis Christianson
# 4                 26  Action,Adventure            7.1           Mark Roper
# ...              ...               ...            ...                  ...
# 84932             51             Drama            7.0      Tamar Guimaraes
# 84933             53         Biography            7.6  Pierre-Henri Gibert
# 84934             \N            Comedy            9.4   Gabriel Athanasiou
# 84935            123             Drama            8.3    Azhar Kinoi Lubis
# 84936            116                \N            8.4         Kiran Gawade
#
# [84937 rows x 9 columns]

# %%
# remove duplicate rows while joining director names

df['directors'] = df['directors'].astype(str)
directors_column = df.groupby(['tconst']).agg({'directors': ', '.join})['directors'].values

df.drop_duplicates(subset='tconst', inplace=True)
df['directors'] = directors_column

df
# Out:
#           tconst                                primaryTitle  \
# 0      tt0038086                   Shiva und die Galgenblume
# 1      tt0079644                               November 1828
# 2      tt0084015                            Goodbye Paradise
# 4      tt0084660                                    Sentinel
# 5      tt0084870                    Memories and Confessions
# ...          ...                                         ...
# 84932  tt9916170                               The Rehearsal
# 84933  tt9916192  Danielle Darrieux: Il est poli d'être gai!
# 84934  tt9916460                                   Pink Taxi
# 84935  tt9916538                         Kuambil Lagi Hatiku
# 84936  tt9916730                                      6 Gunn
#
#                                     originalTitle isAdult  startYear  \
# 0                       Shiva und die Galgenblume       0     1993.0
# 1                                   November 1828       0     2001.0
# 2                                Goodbye Paradise       0     1991.0
# 4                                        Sentinel       0     1993.0
# 5                 Visita ou Memórias e Confissões       0     1993.0
# ...                                           ...     ...        ...
# 84932                                    O Ensaio       0     2019.0
# 84933  Danielle Darrieux: Il est poli d'être gai!       0     2019.0
# 84934                                   Pink Taxi       0     2019.0
# 84935                         Kuambil Lagi Hatiku       0     2019.0
# 84936                                      6 Gunn       0     2017.0
#
#       runtimeMinutes             genres  averageRating  \
# 0                 \N           Thriller            7.0
# 1                140          Drama,War            7.3
# 2                101              Drama            7.2
# 4                 26   Action,Adventure            7.1
# 5                 73  Biography,History            7.1
# ...              ...                ...            ...
# 84932             51              Drama            7.0
# 84933             53          Biography            7.6
# 84934             \N             Comedy            9.4
# 84935            123              Drama            8.3
# 84936            116                 \N            8.4
#
#                              directors
# 0                       Hans Steinhoff
# 1                          Teguh Karya
# 2      Tim Savage, Dennis Christianson
# 4                           Mark Roper
# 5                   Manoel de Oliveira
# ...                                ...
# 84932                  Tamar Guimaraes
# 84933              Pierre-Henri Gibert
# 84934               Gabriel Athanasiou
# 84935                Azhar Kinoi Lubis
# 84936                     Kiran Gawade
#
# [72426 rows x 9 columns]

# %%
#df.to_csv('../data/data.csv', index=False, sep=';')

# %% [markdown]
# # TODO:
# - remover filmes mais antigos que x data
# - filtrar filmes apenas em en
#   - not enough values
# - remover filmes sem sinopse (isto é quando formos fazer o webscrapping ig)
