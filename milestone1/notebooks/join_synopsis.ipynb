# %%
import pandas as pd

# %%
df = pd.read_csv('../processed/data.csv', delimiter=';')
df_synopsis = pd.read_csv('../processed/final_data.csv', delimiter=';')

# %%
df
# Out:
#           tconst                                primaryTitle  \
# 0      tt0038086                   Shiva und die Galgenblume
# 1      tt0079644                               November 1828
# 2      tt0084015                            Goodbye Paradise
# 3      tt0084660                                    Sentinel
# 4      tt0084870                    Memories and Confessions
# ...          ...                                         ...
# 72893  tt9916170                               The Rehearsal
# 72894  tt9916192  Danielle Darrieux: Il est poli d'être gai!
# 72895  tt9916460                                   Pink Taxi
# 72896  tt9916538                         Kuambil Lagi Hatiku
# 72897  tt9916730                                      6 Gunn
#
#                                     originalTitle  isAdult  startYear  \
# 0                       Shiva und die Galgenblume        0     1993.0
# 1                                   November 1828        0     2001.0
# 2                                Goodbye Paradise        0     1991.0
# 3                                        Sentinel        0     1993.0
# 4                 Visita ou Memórias e Confissões        0     1993.0
# ...                                           ...      ...        ...
# 72893                                    O Ensaio        0     2019.0
# 72894  Danielle Darrieux: Il est poli d'être gai!        0     2019.0
# 72895                                   Pink Taxi        0     2019.0
# 72896                         Kuambil Lagi Hatiku        0     2019.0
# 72897                                      6 Gunn        0     2017.0
#
#       runtimeMinutes             genres  averageRating  numVotes  \
# 0                 \N           Thriller            7.0      26.0
# 1                140          Drama,War            7.3      35.0
# 2                101              Drama            7.2      43.0
# 3                 26   Action,Adventure            7.1      12.0
# 4                 73  Biography,History            7.1     379.0
# ...              ...                ...            ...       ...
# 72893             51              Drama            7.0       7.0
# 72894             53          Biography            7.6      16.0
# 72895             \N             Comedy            9.4      18.0
# 72896            123              Drama            8.3       6.0
# 72897            116                 \N            8.4       6.0
#
#                              directors
# 0                       Hans Steinhoff
# 1                          Teguh Karya
# 2      Tim Savage, Dennis Christianson
# 3                           Mark Roper
# 4                   Manoel de Oliveira
# ...                                ...
# 72893                  Tamar Guimaraes
# 72894              Pierre-Henri Gibert
# 72895               Gabriel Athanasiou
# 72896                Azhar Kinoi Lubis
# 72897                     Kiran Gawade
#
# [72898 rows x 10 columns]

# %%
df_synopsis
# Out:
#           tconst                                           synopsis
# 0      tt0038086  \nDetective Dongen, known as Shiva, exposes a ...
# 1      tt0079644  \nA group of Javanese villagers are driven to ...
# 2      tt0084015  \nIt's the last night at the Paradise Inn, a s...
# 3      tt0084660                                                NaN
# 4      tt0084870  \nA docu-drama that follows Manoel de Oliveira...
# ...          ...                                                ...
# 72893  tt9916170  \nIsa, a young artist invited to propose a pro...
# 72894  tt9916192                                                NaN
# 72895  tt9916460  \nOne day Apostolis decides that he wants to b...
# 72896  tt9916538  \nAgra City, India, will be the witness to the...
# 72897  tt9916730  \nVidya Sarvade is a topper of Adarsh Vidyalay...
#
# [72898 rows x 2 columns]

# %%
final_df = df.merge(
  df_synopsis, on='tconst', how='left')

# %%
final_df
# Out:
#           tconst                                primaryTitle  \
# 0      tt0038086                   Shiva und die Galgenblume
# 1      tt0079644                               November 1828
# 2      tt0084015                            Goodbye Paradise
# 3      tt0084660                                    Sentinel
# 4      tt0084870                    Memories and Confessions
# ...          ...                                         ...
# 72893  tt9916170                               The Rehearsal
# 72894  tt9916192  Danielle Darrieux: Il est poli d'être gai!
# 72895  tt9916460                                   Pink Taxi
# 72896  tt9916538                         Kuambil Lagi Hatiku
# 72897  tt9916730                                      6 Gunn
#
#                                     originalTitle  isAdult  startYear  \
# 0                       Shiva und die Galgenblume        0     1993.0
# 1                                   November 1828        0     2001.0
# 2                                Goodbye Paradise        0     1991.0
# 3                                        Sentinel        0     1993.0
# 4                 Visita ou Memórias e Confissões        0     1993.0
# ...                                           ...      ...        ...
# 72893                                    O Ensaio        0     2019.0
# 72894  Danielle Darrieux: Il est poli d'être gai!        0     2019.0
# 72895                                   Pink Taxi        0     2019.0
# 72896                         Kuambil Lagi Hatiku        0     2019.0
# 72897                                      6 Gunn        0     2017.0
#
#       runtimeMinutes             genres  averageRating  numVotes  \
# 0                 \N           Thriller            7.0      26.0
# 1                140          Drama,War            7.3      35.0
# 2                101              Drama            7.2      43.0
# 3                 26   Action,Adventure            7.1      12.0
# 4                 73  Biography,History            7.1     379.0
# ...              ...                ...            ...       ...
# 72893             51              Drama            7.0       7.0
# 72894             53          Biography            7.6      16.0
# 72895             \N             Comedy            9.4      18.0
# 72896            123              Drama            8.3       6.0
# 72897            116                 \N            8.4       6.0
#
#                              directors  \
# 0                       Hans Steinhoff
# 1                          Teguh Karya
# 2      Tim Savage, Dennis Christianson
# 3                           Mark Roper
# 4                   Manoel de Oliveira
# ...                                ...
# 72893                  Tamar Guimaraes
# 72894              Pierre-Henri Gibert
# 72895               Gabriel Athanasiou
# 72896                Azhar Kinoi Lubis
# 72897                     Kiran Gawade
#
#                                                 synopsis
# 0      \nDetective Dongen, known as Shiva, exposes a ...
# 1      \nA group of Javanese villagers are driven to ...
# 2      \nIt's the last night at the Paradise Inn, a s...
# 3                                                    NaN
# 4      \nA docu-drama that follows Manoel de Oliveira...
# ...                                                  ...
# 72893  \nIsa, a young artist invited to propose a pro...
# 72894                                                NaN
# 72895  \nOne day Apostolis decides that he wants to b...
# 72896  \nAgra City, India, will be the witness to the...
# 72897  \nVidya Sarvade is a topper of Adarsh Vidyalay...
#
# [72898 rows x 11 columns]

# %%
final_df.to_csv('data.csv', index=False, sep=';')
